# %%
import requests
import pandas as pd

# Define the base URL for the Toronto Open Data API
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"

# Define the URL to access the 'Toronto Neighborhoods' API
url = base_url + "/api/3/action/package_show"

# Set the parameters to retrieve information about the 'neighbourhoods' package
params = {"id": "neighbourhoods"}

# Send a GET request to retrieve information about the 'neighbourhoods' package
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    package_info = response.json()
    
    # Extract the resources from the package
    resources = package_info['result']['resources']
    
    # Find the resource with the desired data format (e.g., CSV or JSON)
    for resource in resources:
        if resource['format'].lower in ['csv','json']:
            data_url = resource['url']
            data_format = resource['format']
            break

    # Load the data into a DataFrame based on its format
    if data_format == 'json':
        # If the data format is JSON, load it into a DataFrame
        df = pd.read_json(data_url)
    elif data_format == 'csv':
        df= pd.read_csv(data_url)
    
else:
    print("Failed to retrieve requested data from the API.")

# Show response status code
if response. status_code == 200:
    print(response.status_code)
else: 
    print ("Data collection from API unsuccessful")    

# Parse and display the DataFrame
df.head()
# Out:
# 200
#    _id  AREA_ID  AREA_ATTR_ID  PARENT_AREA_ID  AREA_SHORT_CODE  \
# 0    1  2501286      26022481             NaN               30
# 1    2  2501285      26022480             NaN              106
# 2    3  2501284      26022479             NaN               91
# 3    4  2501283      26022478             NaN               48
# 4    5  2501282      26022477             NaN              129
#
#    AREA_LONG_CODE                 AREA_NAME                 AREA_DESC  \
# 0              30  Brookhaven-Amesbury (30)  Brookhaven-Amesbury (30)
# 1             106  Humewood-Cedarvale (106)  Humewood-Cedarvale (106)
# 2              91   Weston-Pelham Park (91)   Weston-Pelham Park (91)
# 3              48    Hillcrest Village (48)    Hillcrest Village (48)
# 4             129     Agincourt North (129)     Agincourt North (129)
#
#                          CLASSIFICATION CLASSIFICATION_CODE  OBJECTID  \
# 0  Not an NIA or Emerging Neighbourhood                 NaN  17818369
# ...

# %%
# Task 2

import requests

topicname = 'dsi_c2_brs'
message = "Today is a snow day - Do you want to build a snowman?"

response = requests.post(f"https://ntfy.sh/{topicname}", data=message)

# %%
## see screenshot of successful output in GitHub
